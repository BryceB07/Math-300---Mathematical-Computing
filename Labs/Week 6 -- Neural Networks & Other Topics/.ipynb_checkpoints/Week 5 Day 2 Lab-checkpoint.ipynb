# %% [markdown]
# # Week 6 Day 2 Lab
# ### Problem 1
# Create a neural network with:
# - 2 input features
# - 8 hidden neurons
# - ReLU activation
# - 1 sigmoid output neuron

# %%
model = Sequential([
    Dense(8, activation="relu", input_shape=(2,)),
    Dense(1, activation="sigmoid")
])

# %% [markdown]
# ### Problem 2
# Create your own dataset and train the model for:
#
# - 50 epochs
# - 100 epochs
# - 300 epochs
#
# Compare the results.

# %%
x = np.random.rand(25,2)
y = np.random.randint(0, 2, size=(25, 1))
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
model.fit(
    x,
    y,
    epochs=300,
    verbose=1
)
# Epochs = 50,    189ms/step - accuracy: 0.6800 - loss: 0.6492
# Epochs = 100,   230ms/step - accuracy: 0.5600 - loss: 0.6700
# Epochs = 300,   144ms/step - accuracy: 0.6800 - loss: 0.6139

# There is a new random dataset eachtime that could be contributing to the accuracy drop and loss increase on epochs = 100 run
# Epochs = 300 was able to shrink the loss while maintaining accuracy over epochs=50
# Out:
# Epoch 1/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.6400 - loss: 0.6594
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6400 - loss: 0.6589
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6400 - loss: 0.6584
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6400 - loss: 0.6578
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6400 - loss: 0.6573
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.6400 - loss: 0.6569
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6400 - loss: 0.6564
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.6400 - loss: 0.6559
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.6400 - loss: 0.6554
# Epoch 10/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.6400 - loss: 0.6549
# Epoch 11/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6400 - loss: 0.6544
# Epoch 12/300
# ...

# %% [markdown]
# ### Problem 3
#
# Replace the optimizer:
#
# ```python
# optimizer="sgd"
# ```
#
# Compare it with:
#
# ```python
# optimizer="adam"
# ```

# %%
x = np.random.rand(25,2)
y = np.random.randint(0, 2, size=(25, 1))
model.compile(
    optimizer="sgd",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
model.fit(
    x,
    y,
    epochs=300,
    verbose=1
)
# Out:
# Epoch 1/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5200 - loss: 0.7450
# Epoch 2/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5200 - loss: 0.7438
# Epoch 3/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5200 - loss: 0.7426
# Epoch 4/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5200 - loss: 0.7414
# Epoch 5/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.5200 - loss: 0.7402
# Epoch 6/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.5200 - loss: 0.7391
# Epoch 7/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5200 - loss: 0.7380
# Epoch 8/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.5200 - loss: 0.7369
# Epoch 9/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.5200 - loss: 0.7358
# Epoch 10/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5200 - loss: 0.7347
# Epoch 11/300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.5200 - loss: 0.7337
# Epoch 12/300
# ...

# %% [markdown]
# I notice that each time the loss decreases, it only moves by 0.0001.
# I think if this were to continue, the loss would continue to decrease.

# %% [markdown]
# ### Problem 4
# Create a neural network for the Iris dataset using:
#
# - Input layer
# - One hidden layer
# - Three output neurons
# - Softmax activation

# %%
import pandas as pd
irisdf = pd.read_csv(r"C:\Users\bryce\GitHub\Math-300---Mathematical-Computing\Datasets\iris.csv")

model = Sequential([
    Dense(8, activation="relu", input_shape=(4,)),
    Dense(3, activation="softmax")
])
# Out:
# C:\Users\bryce\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Week 2 Day 3 Lab

# %% [markdown]
# ## Problem 1
# Import `numpy`, `math`, and `sympy`.

# %%
import numpy as np
import math
import sympy as sp

# %% [markdown]
# ## Problem 2
#
# 1. Write a recursive function `factorial()` that takes in a natural number `n` and computes $n!=n(n-1)(n-2)\cdots3\cdot2\cdot 1$.
# 2. Use `%timeit` to determine how fast your function calculates `factorial(150)`.
# 3. Use `%timeit` to calculate how fast `math.factorial()` calculates the same quantity.
# 4. Were there any differences between the two methods?

# %%
# %timeit math.factorial(150)
def factorial(value):
    answer = 0
    if (value <= 1):
        return value
    else:
        answer += (value * factorial(value - 1))
        return answer
# %timeit factorial(150)
# Out:
# 1.51 μs ± 157 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 30.1 μs ± 685 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# math.factorial is significantly faster

# %% [markdown]
# ## Problem 3
# Recall for a quadratic equation of the form
# $$ax^2 + bx + c = 0
# $$
#
# The solutions are given by the <i>quadratic formula</i>:
#
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# 1. Write a function `quadratic()` that calculates the two roots given by the quadratic formula only if they are real.
# 2. Use `%timeit` to determine how fast your function calculates the roots for $437x^2 - 915x + 478 = 0$.
# 3. Use `%timeit` to calculate how fast `sp.solve()` calculates the same quantities.
# 4. Were there any differences between the two methods?

# %%
x=[]
def quadratic(a, b, c):
    if (b**2 -(4*a*c) >= 0):
        x.append((-b + (math.sqrt((b**2)-(4*a*c)))) / 2*a)
        x.append((-b - (math.sqrt((b**2)-(4*a*c)))) / 2*a)
    else:
        print("no real roots")
# %timeit quadratic(437, -915, 478)
t = sp.symbols('t')
# %timeit sp.solve((437*t**2)-(915*t)+478)
if (x[0] == x[1]):
    print("1 root found")
    print(x)
else:
    print("2 distinct roots at")
    print(x)
# Out:
# 808 ns ± 19.1 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Problem 4
#
# For each of the following functions, use `sympy` calculate the first derivative, the second derivative, and the integral (all with respect to $x$):
#
# 1. $f(x)=x$
# 2. $f(x)=6x^{-1/2}$
# 3. $f(x)=\pi\sqrt{x}+x^5+7$
# 4. $f(x)=x(2x-5)(3+\tan(x))$

# %%
x = sp.symbols('x')
func = [x, (6*x**(-1/2)), ((math.pi)*(math.sqrt(x)) + x**5 + 7), (x*(2*x - 5)*(3 + math.tan(x)))]
def integrand(funclist):
    for i in funclist:
        print(sp.integrate(i, x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 x = sp.symbols('x')
# ----> 2 func = [x, (6*x**(-1/2)), ((math.pi)*(math.sqrt(x)) + x**5 + 7), (x*(2*x - 5)*(3 + math.tan(x)))]
#       3 def integrand(funclist):
#       4     for i in funclist:
#
# File /opt/conda/envs/anaconda-2025.12-py312/lib/python3.12/site-packages/sympy/core/expr.py:375, in Expr.__float__(self)
#     373 if result.is_number and result.as_real_imag()[1]:
#     374     raise TypeError("Cannot convert complex to float")
# --> 375 raise TypeError("Cannot convert expression to float")
#
# TypeError: Cannot convert expression to float

# %% [markdown]
# ## Problem 5
#
# From yesterday, we calculated <i>numerically</i> what the derivative of $\sin(x)$ is.
# 1. Using sympy, calculate derivative at 0.
# 2. Using sympy, evaluate the limit definition of the derivative for $f(x)=\sin(x)$:
# $$f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}
# $$

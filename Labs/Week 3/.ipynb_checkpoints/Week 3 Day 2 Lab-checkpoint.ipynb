# %% [markdown]
# # Week 3 Day 2 Lab
#
# ### Problem 1
# Plot the function $f(x)=x^2$ for $x\in [-1,1]$ using `np.linspace()` with 10, 100, 1000 slices. Make sure your plot is as informative as possible.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import numpy as np
data = np.linspace(-1,1,1000)
plt.plot(data,data**2, label = 'X Squared')
plt.legend()
plt.title('Title')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# ### Problem 2
# Pick a function $f(x)$ you like and plot some values using `plt.scatter()`. Make sure your plot is as informative as possible.

# %%
x = np.linspace(-5,5,50)
F = x**3
plt.scatter(x,F, label='X Cubed')
plt.legend()
plt.title('Title')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %% [markdown]
# ### Problem 3
# Download the "Horses.xlsx" or "Horses.csv" file.
# - Read the file in using `pandas`
# - Plot the values using whatever plot type you like. Make sure your plot is as informative as possible.

# %%
horsedata = pd.read_excel(r"C:\Users\bryce\GitHub\Math-300---Mathematical-Computing\Labs\Week 3\Datasets\Horses.xlsx")
horsedata
# Out:
#   Horse  Race Finish Time
# 0     A              1230
# 1     B              1309
# 2     C              1279
# 3     D              1237
# 4     E              1328
# 5     F              1490
# 6     G              1243
# 7     H              1325
# 8     I              1428

# %% [markdown]
# ### Problem 4
# Download the "WA_County_Boundaries.shp" file.
# - Plot the state using `name_of_file_read.plot()`
# - Plot some information about the state by extracting two columns of data.

# %%
import geopandas as gpd

# %%
data = gpd.read_file(r"C:\Users\bryce\GitHub\Math-300---Mathematical-Computing\Labs\Week 3\Datasets\WA_County_Boundaries\WA_County_Boundaries.shp")
data.plot(column='JURISDIC_3', legend=True)
# Out:
# <Axes: >
